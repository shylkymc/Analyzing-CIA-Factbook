# %%
import pandas as  pd
import sqlite3

# %%
conn= sqlite3.connect("factbook.db")

# %%
q= "SELECT * FROM sqlite_master WHERE type='table';"
pd.read_sql_query(q,conn)
# Out:
#     type             name         tbl_name  rootpage  \
# 0  table  sqlite_sequence  sqlite_sequence         3
# 1  table            facts            facts        47
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "facts" ("id" INTEGER PRIMARY KEY...

# %%
cursor= conn.cursor()
cursor.execute(q).fetchall()
# Out:
# [('table',
#   'sqlite_sequence',
#   'sqlite_sequence',
#   3,
#   'CREATE TABLE sqlite_sequence(name,seq)'),
#  ('table',
#   'facts',
#   'facts',
#   47,
#   'CREATE TABLE "facts" ("id" INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL, "code" varchar(255) NOT NULL, "name" varchar(255) NOT NULL, "area" integer, "area_land" integer, "area_water" integer, "population" integer, "population_growth" float, "birth_rate" float, "death_rate" float, "migration_rate" float)')]

# %%
q1= "select * from facts limit 5 "
pd.read_sql_query(q1,conn)
# Out:
#    id code         name     area  area_land  area_water  population  \
# 0   1   af  Afghanistan   652230     652230           0    32564342
# 1   2   al      Albania    28748      27398        1350     3029278
# 2   3   ag      Algeria  2381741    2381741           0    39542166
# 3   4   an      Andorra      468        468           0       85580
# 4   5   ao       Angola  1246700    1246700           0    19625353
#
#    population_growth  birth_rate  death_rate  migration_rate
# 0               2.32       38.57       13.89            1.51
# 1               0.30       12.92        6.58            3.30
# 2               1.84       23.67        4.31            0.92
# 3               0.12        8.13        6.96            0.00
# 4               2.78       38.78       11.49            0.46

# %%
q2= " select min(population) min_pop, max(population) max_pop, min(population_growth) min_growth, max(population_growth) max_growth from facts"
pd.read_sql_query(q2,conn)
# Out:
#    min_pop     max_pop  min_growth  max_growth
# 0        0  7256490011         0.0        4.02

# %%
q3= "select * from facts where population == (select max(population) from facts) or population==(select min(population) from facts)"
pd.read_sql_query(q3,conn)
# Out:
#     id code        name  area  area_land area_water  population  \
# 0  250   ay  Antarctica  None   280000.0       None           0
# 1  261   xx       World  None        NaN       None  7256490011
#
#    population_growth  birth_rate  death_rate migration_rate
# 0                NaN         NaN         NaN           None
# 1               1.08        18.6         7.8           None

# %%
q4= "select * from facts where population==0 or population== 7256490011"
pd.read_sql_query(q4,conn)
# Out:
#     id code        name  area  area_land area_water  population  \
# 0  250   ay  Antarctica  None   280000.0       None           0
# 1  261   xx       World  None        NaN       None  7256490011
#
#    population_growth  birth_rate  death_rate migration_rate
# 0                NaN         NaN         NaN           None
# 1               1.08        18.6         7.8           None

# %% [markdown]
# The max population and min population values show the useless data to analyze.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig= plt.figure(figsize=(15,15))
ax= fig.add_subplot(111)

q5= "select population, population_growth, birth_rate, death_rate from facts where population != 0 and population !=7256490011 "
pd.read_sql_query(q5,conn).hist(ax=ax)
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2885: UserWarning:
#
# To output multiple subplots, the figure containing the passed axes is being cleared
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f69e6a6a5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69e499eef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69e496b6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69e49299b0>]],
#       dtype=object)

# %%
q6="select name country, cast(population as float)/cast(area as float) density from facts where population != 0 and population!=7256490011 "
pd.read_sql_query(q6,conn)
# Out:
#                                            country      density
# 0                                      Afghanistan    49.927697
# 1                                          Albania   105.373522
# 2                                          Algeria    16.602211
# 3                                          Andorra   182.863248
# 4                                           Angola    15.741841
# 5                              Antigua and Barbuda   209.131222
# 6                                        Argentina    15.620733
# 7                                          Armenia   102.759708
# 8                                        Australia     2.938944
# 9                                          Austria   103.319979
# 10                                      Azerbaijan   112.942032
# 11                                    Bahamas, The    23.385951
# 12                                         Bahrain  1771.859211
# 13                                      Bangladesh  1138.069143
# 14                                        Barbados   675.823256
# 15                                         Belarus    46.193107
# 16                                         Belgium   370.937271
# 17                                          Belize    15.125359
# 18                                           Benin    92.776252
# 19                                          Bhutan    19.323827
# 20                                         Bolivia     9.831666
# 21                          Bosnia and Herzegovina    75.532844
# 22                                        Botswana     3.752117
# 23                                          Brazil    23.986065
# 24                                          Brunei    74.526626
# 25                                        Bulgaria    64.817441
# 26                                    Burkina Faso    69.043348
# 27                                           Burma    83.242739
# 28                                         Burundi   385.996263
# 29                                        Cambodia    86.771928
# ..                                             ...          ...
# 210                                          Aruba   623.122222
# 211                                        Curacao   334.247748
# 212                                   Sint Maarten  1167.323529
# 213                                   Cook Islands    41.686441
# 214                                           Niue     4.576923
# 215                                        Tokelau   111.416667
# 216                                       Svalbard     0.030172
# 217                                       Akrotiri   127.642276
# 218                                       Anguilla   180.417582
# 219                                        Bermuda  1299.925926
# 220                         British Virgin Islands   221.549669
# 221                                 Cayman Islands   212.469697
# 222                                       Dhekelia   120.769231
# 223              Falkland Islands (Islas Malvinas)     0.276103
# 224                                      Gibraltar  4876.333333
# 225                                       Guernsey   847.179487
# 226                                         Jersey   838.741379
# 227                                    Isle of Man   153.050699
# 228                                     Montserrat    51.382353
# 229                               Pitcairn Islands     1.021277
# 230  Saint Helena, Ascension, and Tristan da Cunha    25.308442
# 231                       Turks and Caicos Islands    53.037975
# 232                                 American Samoa   273.080402
# 233                                           Guam   297.398897
# 234                       Northern Mariana Islands   112.810345
# 235                                    Puerto Rico   260.920673
# 236                                 Virgin Islands    54.227225
# 237                                     Gaza Strip  5191.819444
# 238                                      West Bank   475.318430
# 239                                 Western Sahara     2.146113
#
# [240 rows x 2 columns]

# %%
pd.read_sql_query(q6,conn).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f69e45c79b0>]],
#       dtype=object)

# %%
q
